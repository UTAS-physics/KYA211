# %% [markdown]
# # Section 2: Data processing
#
#
# This notebook contains the practical `python` content for the second computational lab of _KYA211: Waves and Kinetic Theory_ at the University of Tasmania.
#
# **Version**: 1.0
# **Created**: 06/03/2026 (AJM)
# **Updated**: 12/03/2026 (AJM)

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#   <h4 class="alert-heading"><b>❓Exercise 0:</b> Importing packages </span><span style="float: right">0 marks</span></h4>
#
#   <hr>
#   <p class="mb-0">We will need to use a range of packages. Import the packages
#       <ul>
#           <li><code>numpy</code></li>
#           <li><code>matplotlib.pyplot</code></li>
#           <li><code>pandas</code></li>
#           <li><code>scipy</code></li>
#       </ul>
# and use the shorthand of <code>np</code>, <code>plt</code>, and <code>pd</code></p>
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#   <h4 class="alert-heading"><b>❓Exercise 1:</b> Listopia </span><span style="float: right">2 marks</span></h4>
#
#   <hr>
#   <p class="mb-0">List comprehension can be used to make a list of decades. <b>Do not</b> use list comprehension, but rather use <code>numpy</code> to produce a list of decades, from 1e-6 through to 1e6.</p>
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#   <h4 class="alert-heading"><b>❓Exercise 2:</b> Importing data using <code>numpy</code> </span><span style="float: right">2 marks</span></h4>
#
#   <hr>
#   <p class="mb-0">We are going to be looking at some data sets. The first data set we are going to look at is called <code>02 - data-papillon.csv</code> and has three columns: t, x, and y. Using the same function as last time (<code>np.genfromtxt</code>), import the content from the file and label it usefully, for example:
#
# <pre><code>
#     data_from_numpyimport = ...
#
# </code></pre>
# <p></p>
# <p>and then generate arrays for the t, x, and y data of said array, and store these with the labels <code>t_np</code>, <code>x_np</code>, and <code>y_np</code></p>
#
#
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading"><b>✅ Hint</b></h4>
#   <hr>
#   <p class="mb-0">If you cannot remember the syntax for this operation, have a look at the <a href=https://numpy.org/devdocs/reference/generated/numpy.genfromtxt.html>documentation</a> </p>
# </div>
#
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#   <h4 class="alert-heading"><b>❓Exercise 3:</b> Importing data using <code>pandas</code> </span><span style="float: right">1 marks</span></h4>
#
#   <hr>
#   <p class="mb-0">Now we want to import the same data set, but this time using the <code>pandas.read_csv()</code> function. You should make a label to store your data, for example:
#
# <pre><code>
#     data = pandas.read_csv()
#
# </code></pre>
#
# <p></p>
#
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading"><b>✅ Hint</b></h4>
#   <hr>
#   <p class="mb-0">The syntax for this operation can be found <a href=https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html>here</a> </p>
# </div>
#
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#   <h4 class="alert-heading"><b>❓Exercise 4:</b> <code>pandas</code> party </span><span style="float: right">2 marks</span></h4>
#
#   <hr>
#   <p class="mb-0">You can now extract content from the object created by pandas. To get the content stored in the column of <code>data</code>, you can use the label of the column:
#
# <pre><code>
#     desired_column = data('column_name')
#
# </code></pre>
# <p></p>
# <p>Use this (or otherwise), generate the arrays for the t, x, and y data and store these with the labels <code>t_pd</code>, <code>x_pd</code>, and <code>y_pd</code></p>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#   <h4 class="alert-heading"><b>❓Exercise 5:</b> Emergence </span><span style="float: right">3 marks</span></h4>
#
#   <hr>
#   <p class="mb-0">Verify explicitly that the arrays extracted using <code>pandas</code> and <code>numpy</code> are identical.</p>
#
# <p></p>
#
# <p>Now make two plots:
# <ol>
#     <li>One plot showing a plot of <i>both</i> t vs x and t vs y </li>
#     <li>One plot showing x vs y </li>
# </ol>
#
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading"><b>✅ Hint</b></h4>
#   <hr>
#   <p class="mb-0">You should use reasonable parameters to well display the charateristics of any data. The functions <code>plt.xlim(x_min,x_max)</code> and the related <code>plt.ylim</code> may prove useful.</p>
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#   <h4 class="alert-heading"><b>❓Exercise 6:</b> A series of unfortunate events </span><span style="float: right">10 marks</span></h4>
#
#   <hr>
#   <p class="mb-0">A spectroscopy experiment was performed on a sample: a light with uniform spectral density was directed onto an unknown fluid, and the fluorescence from this fluid was collected. Such an experiment is an excellent way to collect a material "fingerprint"; however the data must be accurate to determine anything useful. The experiment was carefully conducted, but the execution was far from perfect.</p>
#
#   <p class="mb-0">The experimentalist well documented their procedure in their logbook, so we know that</p>
#
#   <ul>
#     <li>Data were collected over 400 seconds, with the collected spectrum running from 400 - 800 nm.</li>
#     <li>The photodiode occassionally malfunctions and this is recorded as a stupid number, inconsistent with the other data.</li>
#     <li>The apparatus was accidentally knocked half way through the experiment, which resulted in shift in the detected intensity.</li>
#     <li>The spectrometer has a internal drift of 468.75 microunits per second.</li>
#     <li>The lights were left on for the experiment, which contributed to the recorded spectrum. Fortunately, a background spectrum was recorded and is present in <code>02 - data-background</code></li>
#     <li>The export of the data seemed to result in the data being shuffled</li>
#   </ul>
#
#   <p class="mb-0">Your task is to import the data, which is contained within the file <code>02 - data-spectroscopy</code> and wrangle it into a useful from. This means correcting for the listed mistakes, and producing a clean plot of the fluorescence spectrum. As an optional extra, you can try writing a routine to find the peaks in the spectrum.</p>
#
#   <p class="mb-0"><b>Note:</b> Use seperate cells for each part of the question, and please use comments to explain what you are doing, both in code and as a general way to follow your solution to the problem</p>
#
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading"><b>✅ Hint:</b> Useful functions and snippits</h4>
#   <hr>
#   <p class="mb-0">You may find some utility from the functions below:</p>
#     <ul>
#       <li><code>pandas.DataFrame.sort_values()</code></li>
#       <li><code>numpy</code> and <code>pandas</code> have maximum and minimum finding functions, <code>max</code> and <code>min</code> </li>
#       <li><code>np.diff()</code> will produce an array with elements formed by the difference between adjacent elements</li>
#       <li><code>np.where()</code> can identify where a condition is satisfied</li>
#     </ul>
#
# A basic plotting snippit appears below:
# <pre><code>
#     # 0. Optional, but useful. Initialisation of plots is a whole things...
#     fig = plt.figure(figsize=(8, 4))
#
#     # 1. Make the plot
#     plt.plot(x_vals, y_vals, label = 'title')
#
#     # 2. Customise the formatting
#     plt.title('Plot label')
#     plt.xlabel('X axis label')
#     plt.ylabel('Y axis label')
#     plt.legend()
#
# </code></pre>
#
# </div>
#
# </div>

# %%
# Section 1: Import the data

# %%
# Section 2: Remove silly values

# %%
# Section 3: Remove the discontinuity

# %%
# Section 4: Correct the drift

# %%
# Section 5: Remove the background

# %%
# Section 6 (optional): Find the peaks

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#   <h4 class="alert-heading"><b>❓Exercise 7:</b> My first experiment </span><span style="float: right">10 marks</span></h4>
#
#   <hr>
#   <p class="mb-0">We are now going to run a full computational experiment (i.e. a simulation). The goal will be to predict the the final position of a projectile which is launched with some initial velocity. Let us imagine that we have a catapult-like device which we can tune the magnitude of the initial velocity, and we also have a fixture which we can use to set the elevation of the launch velocity. We then want to introduce some uncertainty into our launch velocity and angle, and see the consequences. Explicitly, you should quantify the spread of final positions, and comment on whether this value is consistent with your expectations.</p>
#
#   <p class="mb-0">When solving a problem like this, it is important to have a clear plan, so in this case, I am going to outline the approach <b>I</b> would take. In this case, I ask you to follow my plan, but in future exerscises, feel free to follow your own approach (unless specified otherwise)</p>
#
#   <ol>
#     <li>What are the equations of motion? I will need expressions for both the x and y components of the position, which will be based on initial values for the velocity and angle.</li>
#     <li>Do a test: make a plot of the trajectory of the projectile for some values. This will mean that I need to make a list of x and y positions versus time. Perhaps I will need to convert my expressions for displacement into functions.</li>
#     <li>We will then need to change our initial values for the trajectory into arrays with some distribution to model an uncertainty, and then calculate the final position of all the projectiles. I suspect a histogram would be a useful way to display these data. I imagine that a pretty plot could be produced from displaying <i>all</i> trajectories, but it would be difficult to ensure this plot wasn't just a mess - maybe this is optional.</li>
#     <li>Quantify the results: what is the spread in final position compared to the input variables? Does this agree with what you would expect from the theoretical statistical framework? Maybe I can compare values, in addition make a plot of what might be expected, and what was "observed".</li>
#   </ol>
#
#   <p class="mb-0"><b>Note:</b> Use seperate cells for each part of the question, and please use comments to explain what you are doing, both in code and as a general way to follow your solution to the problem</p>
#
# <div class="alert alert-success" role="alert">
#   <h4 class="alert-heading"><b>✅ Hint:</b> Useful functions and snippits</h4>
#   <hr>
#   <p class="mb-0">You may find some utility from the functions below:</p>
#     <ul>
#       <li><code>np.deg2rad()</code> and/or <code>np.rad2deg()</code>: useful for converting between degrees and radians, noting that trig functions assume inputs in radians </li>
#       <li><code>plt.hist()</code>: Used to generate histograms</li>
#     </ul>
# </div>
#
# </div>

# %%
# Part 1

# %%
# Part 2

# %%
# Part 3

# %%
# Part 4
