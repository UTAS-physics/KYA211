# %% [markdown]
# # Section 2: Data processing
#
#
# This notebook is used to produce a `python` [RISE](https://rise.readthedocs.io/en/latest/) slideshow to accompany the first section of the introduction to `python` content for practical component of _KYA211: Waves and Kinetic Theory_ at the University of Tasmania.
#
# **Version**: 1.0
# **Created**: 06/03/2026 (AJM)
# **Updated**: 06/03/2026 (AJM)

# %% [markdown]
# # Experiment analysis

# %% [markdown]
# KYA211, Andy McCulloch

# %% [markdown]
# ## Feedback

# %% [markdown]
# 1. Use comments (or even markdown) to say what you are doing

# %% [markdown]
# 2. Cite where code comes from

# %% [markdown]
# 3. Veryify your outputs!

# %% [markdown]
# ## Experimental labs

# %% [markdown]
# <div>
# <center>
#     <img src="03/timeline.png" width="600"/>
# </center>
# </div>

# %% [markdown]
# Labs begin in week 7, and take place in the 2nd-year lab, room 233

# %% [markdown]
# You will do 2 experiments for the semester, and you should have already uploaded your lab induction certificate to MyLO and selected your lab preferences

# %% [markdown]
# You will be allocated experiments and **you must** complete the prelab questions prior to attending the first class

# %% [markdown]
# Labs will be taught by myself and Tom, and you will be assessed on your performance in class and your logbook

# %% [markdown]
# ## The experimental logbook

# %% [markdown]
# A logbook is distinct from a lab report!

# %% [markdown]
# The information between the two is essentially identical; however, a logbook is a real-time document, whereas the report is compiled after the experiment

# %% [markdown]
# Information on logbooks can be found on the [lab website](https://polus.utasphys.cloud.edu.au/reference/experiment/#logbooks), but you have been making one for this workshop!

# %% [markdown]
# An introduction to the labs will take place during the first lab session, just make sure that you have completed your safety induction, completed your prelabs, and come prepared to do physics!
